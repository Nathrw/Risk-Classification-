# %% [markdown]
# # Risk Classification Project

# %% [markdown]
# ## Project Overview:
# The Classifying Application Risk project involves developing a "production-ready" machine learning solution to distinguish between high-risk (malicious) and low-risk (benign) software applications. Using a dataset characterised by high sparsity and complex feature relationships, the primary goal is to build a robust classification pipeline—from raw data parsing to model deployment—that achieves at least 90% precision and recall on high-risk targets. Key objectives include implementing advanced feature engineering (such as behavioural "intensity" metrics), selecting a high-performing model like XGBoost, and packaging the final solution with clear developer instructions and a dedicated test script to ensure seamless integration into an antivirus product.

# %%
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split, RandomizedSearchCV
import time
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve, auc
from sklearn.metrics import (
   accuracy_score,
   precision_score,
   recall_score,
   f1_score)
from sklearn.utils.class_weight import compute_sample_weight 
import dtreeviz as dtree
import graphviz
import zipfile
import os
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import numpy as np
from xgboost import XGBClassifier
from scipy.stats import uniform, randint

# %% [markdown]
# Loading CSV and Mapping

# %%
mapping = pd.read_csv('feature_name_to_number_mapping.csv')
f_dict = dict(zip(mapping['feature_number'], mapping['feature_name']))

# %% [markdown]
# Extracting Project 2 Raw Data

# %%
zip_file = 'project2_raw_data.zip'
extr_dict = 'extracted_monthly_data'

# %%
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall(extr_dict)
    print(f"Exracted zip contents to: {extr_dict}")
# Out:
# Exracted zip contents to: extracted_monthly_data

# %% [markdown]
# ### 1: Creating a function to process every .txt in the zip

# %%
def combine_files(directory):
    data = []

    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            path = os.path.join(directory, filename)

            with open(path, 'r') as f:
                for line in f:
                    strip = line.strip().split()
                    if not strip: continue

                    risk_score = float(strip[0])
                    target = 1 if risk_score >= 0.3 else 0

                    rows = {'target_high_risk': target, 'source_month': filename}

                    for item in strip[1:]:
                        f_num, f_val = item.split(':')
                        f_name = f_dict.get(int(f_num), f"feat_{f_num}")
                        rows[f_name] = float(f_val)

                    data.append(rows)

    pr_df = pd.DataFrame(data)
    return pr_df

# %% [markdown]
# Combining files

# %%
df = combine_files(extr_dict)

# %% [markdown]
# When initially performing XGBoost, two features were missing. The code below ensures all features are included

# %%
df = combine_files(extr_dict)

master_features = list(f_dict.values())

all_cols = ['target_high_risk', 'source_month'] + master_features
df = df.reindex(columns=all_cols, fill_value=0)

# %% [markdown]
# ### 2: Train, test, validation splitting

# %%
# 70% train 30% fill
train_df, fill_df = train_test_split(df, test_size=0.3, random_state=42)

# 30% filler set split into val and test (15%)
val_df, test_df = train_test_split(fill_df, test_size=0.5, random_state=42)

# Saving splits to CSV - avoiding accidental data leakage
train_df.to_csv('train.csv', index=False)
val_df.to_csv('val.csv', index=False)
test_df.to_csv('test.csv', index=False)

# %% [markdown]
# ### 3: Data Cleaning

# %% [markdown]
# Viewing Data

# %%
train_df.head()

train_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75499 entries, 68243 to 15795
# Data columns (total 485 columns):
#  #    Column                                 Dtype
# ---   ------                                 -----
#  0    target_high_risk                       int64
#  1    source_month                           object
#  2    NtOpenSection                          float64
#  3    NtWaitForSingleObject                  int64
#  4    GetAsyncKeyState                       float64
#  5    NtDeleteValueKey                       float64
#  6    WSARecv                                float64
#  7    getaddrinfo                            float64
#  8    InternetGetConnectedState              float64
#  9    NtCreateEvent                          int64
#  10   GetFileVersionInfoSizeW                float64
#  11   GetAdaptersAddresses                   float64
#  12   NtMakeTemporaryObject                  int64
#  13   NtRenameKey                            float64
#  14   HttpSendRequestA                       float64
#  15   GetLocalTime                           int64
#  16   NetUserGetLocalGroups                  float64
#  17   FindFirstFileExW                       float64
#  18   CryptRetrieveObjectByUrlW              int64
#  19   NtReadVirtualMemory                    float64
#  20   HttpAddRequestHeadersA                 int64
#  21   RegOpenKeyExW                          float64
#  22   NtDelayExecution                       float64
#  23   InternetCrackUrlA                      float64
#  24   SetErrorMode                           float64
#  25   ShellExecuteExW                        float64
#  26   RegOpenKeyExA                          float64
#  27   HttpSendRequestW                       float64
#  28   HttpAddRequestHeadersW                 int64
#  29   GetCursorPos                           float64
#  30   JsEval                                 int64
#  31   GetUserNameW                           float64
#  32   WinHttpSetTimeouts                     int64
#  33   WaitForDebugEvent                      int64
#  34   FindWindowExA                          float64
#  35   GetUserNameA                           float64
#  36   NtCreateFile                           float64
#  37   TransmitFile                           int64
#  38   GetSystemTimeAsFileTime                float64
#  39   WinHttpOpen                            int64
#  40   NtLoadDriver                           float64
#  41   GetDiskFreeSpaceA                      int64
#  42   NtCreateProcess                        int64
#  43   NtDeleteKey                            float64
#  44   WinHttpQueryHeaders                    int64
#  45   InternetSetOptionA                     float64
#  46   CryptGenKey                            float64
#  47   recvfrom                               float64
#  48   CryptEncrypt                           int64
#  49   sendto                                 float64
#  50   NtSuspendThread                        float64
#  51   NtQueryInformationFile                 float64
#  52   RegCreateKeyExW                        float64
#  53   GetSystemTime                          int64
#  54   DeviceIoControl                        float64
#  55   WSASendTo                              float64
#  56   FindFirstChangeNotificationW           int64
#  57   NtQueryKey                             float64
#  58   OpenServiceA                           float64
#  59   WriteProcessMemory                     float64
#  60   WSARecvFrom                            float64
#  61   NtSetContextThread                     float64
#  62   HttpEndRequestW                        int64
#  63   RegQueryValueExA                       float64
#  64   RemoveDirectoryW                       float64
#  65   EnumWindows                            float64
#  66   OpenServiceW                           float64
#  67   NtSetValueKey                          float64
#  68   LookupPrivilegeValueW                  float64
#  69   NtQueryValueKey                        float64
#  70   RegCreateKeyExA                        float64
#  71   RemoveDirectoryA                       float64
#  72   HttpEndRequestA                        int64
#  73   RegQueryValueExW                       float64
#  74   WSASocketW                             float64
#  75   NetUserGetInfo                         float64
#  76   SetWindowsHookExW                      float64
#  77   ExitWindowsEx                          float64
#  78   WSASend                                float64
#  79   WinHttpGetProxyForUrl                  int64
#  80   StartServiceA                          float64
#  81   NtDeviceIoControlFile                  float64
#  82   NtReadFile                             float64
#  83   CryptCreateHash                        float64
#  84   FindWindowExW                          float64
#  85   NtWriteFile                            float64
#  86   LdrGetDllHandle                        float64
#  87   WinHttpSendRequest                     int64
#  88   RtlDecompressBuffer                    float64
#  89   NtQuerySystemInformation               float64
#  90   NtEnumerateValueKey                    float64
#  91   CreateDirectoryExW                     float64
#  92   CreateThread                           float64
#  93   NtLoadKey                              float64
#  94   SetupDiGetClassDevsA                   int64
#  95   SetUnhandledExceptionFilter            float64
#  96   NtQuerySystemTime                      int64
#  97   GetVolumeNameForVolumeMountPointW      float64
#  98   DnsQuery_A                             float64
#  99   CryptDecrypt                           float64
#  100  recv                                   float64
#  101  SetupDiGetClassDevsW                   int64
#  102  NtProtectVirtualMemory                 float64
#  103  SHGetFolderPathW                       float64
#  104  RegDeleteValueW                        float64
#  105  GetDiskFreeSpaceExA                    int64
#  106  socket                                 float64
#  107  RegSetValueExW                         float64
#  108  WriteConsoleA                          float64
#  109  LdrGetProcedureAddress                 float64
#  110  NtOpenThread                           float64
#  111  CopyFileA                              float64
#  112  CopyFileW                              float64
#  113  RegSetValueExA                         float64
#  114  GetDiskFreeSpaceExW                    float64
#  115  NtEnumerateKey                         float64
#  116  NtOpenDirectoryObject                  float64
#  117  LdrLoadDll                             float64
#  118  NtWriteVirtualMemory                   float64
#  119  URLDownloadToFileW                     float64
#  120  WriteConsoleW                          float64
#  121  CreateToolhelp32Snapshot               float64
#  122  SendNotifyMessageA                     float64
#  123  RegCloseKey                            float64
#  124  NtOpenEvent                            int64
#  125  NtSetInformationFile                   float64
#  126  HttpSendRequestExW                     int64
#  127  NtCreateKey                            float64
#  128  WinHttpConnect                         int64
#  129  MoveFileWithProgressW                  float64
#  130  ioctlsocket                            float64
#  131  WSAStartup                             float64
#  132  NtTerminateThread                      float64
#  133  DbgUiWaitStateChange                   int64
#  134  NtTerminateProcess                     float64
#  135  send                                   float64
#  136  shutdown                               float64
#  137  SendNotifyMessageW                     float64
#  138  COleScript_ParseScriptText             int64
#  139  HttpSendRequestExA                     int64
#  140  select                                 float64
#  141  NtQueryFullAttributesFile              float64
#  142  CreateRemoteThread                     float64
#  143  GetSystemMetrics                       float64
#  144  NtQueueApcThread                       float64
#  145  WSASocketA                             float64
#  146  CreateServiceA                         float64
#  147  WinHttpSetOption                       int64
#  148  InternetCloseHandle                    float64
#  149  DeleteFileA                            int64
#  150  NtLoadKey2                             int64
#  151  CryptExportKey                         float64
#  152  CryptImportPublicKeyInfo               int64
#  153  NtAllocateVirtualMemory                float64
#  154  ReadProcessMemory                      float64
#  155  CreateDirectoryW                       float64
#  156  DeleteFileW                            float64
#  157  VirtualProtectEx                       int64
#  158  CreateServiceW                         float64
#  159  listen                                 float64
#  160  NtCreateThread                         float64
#  161  GetComputerNameW                       float64
#  162  NtResumeThread                         float64
#  163  CryptAcquireContextA                   float64
#  164  setsockopt                             float64
#  165  InternetReadFile                       float64
#  166  CoCreateInstance                       float64
#  167  RegEnumKeyExW                          float64
#  168  FindNextFileW                          int64
#  169  ObtainUserAgentString                  float64
#  170  CryptAcquireContextW                   float64
#  171  DnsQuery_W                             float64
#  172  NtCreateNamedPipeFile                  int64
#  173  GetComputerNameA                       float64
#  174  NtReplaceKey                           int64
#  175  RegEnumKeyExA                          float64
#  176  closesocket                            float64
#  177  NtGetContextThread                     float64
#  178  RtlCreateUserThread                    float64
#  179  RegEnumValueW                          float64
#  180  NtCreateSection                        float64
#  181  StartServiceW                          float64
#  182  WinHttpGetIEProxyConfigForCurrentUser  int64
#  183  SetWindowsHookExA                      float64
#  184  NtOpenMutant                           float64
#  185  InternetOpenA                          float64
#  186  NtDeleteFile                           float64
#  187  NSPStartup                             int64
#  188  IsDebuggerPresent                      float64
#  189  RegEnumValueA                          float64
#  190  WinHttpReceiveResponse                 int64
#  191  InternetOpenW                          float64
#  192  CreateProcessInternalW                 float64
#  193  connect                                float64
#  194  RegDeleteKeyA                          float64
#  195  NtDuplicateObject                      float64
#  196  RegNotifyChangeKeyValue                int64
#  197  NtQueryMultipleValueKey                int64
#  198  HttpOpenRequestA                       float64
#  199  OpenSCManagerW                         float64
#  200  GetSystemInfo                          float64
#  201  NtCreateProcessEx                      float64
#  202  accept                                 float64
#  203  FindWindowW                            float64
#  204  ControlService                         float64
#  205  NtClose                                float64
#  206  RegDeleteKeyW                          float64
#  207  CryptHashData                          float64
#  208  NtOpenProcess                          float64
#  209  FindWindowA                            float64
#  210  HttpOpenRequestW                       float64
#  211  NtFreeVirtualMemory                    float64
#  212  Process32NextW                         float64
#  213  GetLastInputInfo                       int64
#  214  InternetConnectW                       float64
#  215  UnhookWindowsHookEx                    float64
#  216  InternetWriteFile                      float64
#  217  GetDiskFreeSpaceW                      float64
#  218  NtSaveKeyEx                            float64
#  219  RegEnumKeyW                            float64
#  220  InternetConnectA                       float64
#  221  NtSaveKey                              float64
#  222  SetWindowLongA                         int64
#  223  CDocument_write                        int64
#  224  WSAConnect                             int64
#  225  RegDeleteValueA                        float64
#  226  CopyFileExW                            float64
#  227  NtMapViewOfSection                     float64
#  228  SetupDiGetDeviceRegistryPropertyW      int64
#  229  Process32FirstW                        float64
#  230  DeleteService                          float64
#  231  LsaOpenPolicy                          int64
#  232  NtOpenFile                             float64
#  233  RegQueryInfoKeyW                       float64
#  234  NtUnmapViewOfSection                   float64
#  235  NtQueryDirectoryFile                   float64
#  236  NetGetJoinInformation                  float64
#  237  FindFirstFileExA                       float64
#  238  gethostbyname                          float64
#  239  DecodeImage                            int64
#  240  NtQueryAttributesFile                  float64
#  241  RegQueryInfoKeyA                       float64
#  242  NtCreateMutant                         float64
#  243  GetAddrInfoW                           float64
#  244  InternetOpenUrlA                       float64
#  245  WSAAccept                              float64
#  246  bind                                   float64
#  247  NtOpenKey                              float64
#  248  InternetCrackUrlW                      float64
#  249  DnsQuery_UTF8                          int64
#  250  CoInternetSetFeatureEnabled            int64
#  251  NtResumeProcess                        int64
#  252  OpenSCManagerA                         float64
#  253  GetFileVersionInfoW                    float64
#  254  CryptDecodeObjectEx                    float64
#  255  InternetOpenUrlW                       float64
#  256  OpenSCManagerA                         float64
#  257  WinHttpOpenRequest                     int64
#  258  SetupDiGetDeviceRegistryPropertyA      int64
#  259  msxml3.dll                             int64
#  260  winsta.dll                             int64
#  261  icm32.dll                              int64
#  262  sqlite3.dll                            int64
#  263  msls31.dll                             int64
#  264  pstorec.dll                            int64
#  265  mpr.dll                                int64
#  266  iertutil.dll                           int64
#  267  crypt32.dll                            int64
#  268  clbcatq.dll                            int64
#  269  advapi32.dll                           int64
#  270  ole32.dll                              int64
#  271  ws2_32.dll                             int64
#  272  davclnt.dll                            int64
#  273  linkinfo.dll                           int64
#  274  mlang.dll                              int64
#  275  sqlite.dll                             int64
#  276  imgutil.dll                            int64
#  277  setupapi.dll                           int64
#  278  iphlpapi.dll                           int64
#  279  mswsock.dll                            int64
#  280  avicap32.dll                           int64
#  281  nss3.dll                               int64
#  282  msvcrt.dll                             int64
#  283  rpcrt4.dll                             int64
#  284  ieui.dll                               int64
#  285  ieproxy.dll                            int64
#  286  urlmon.dll                             int64
#  287  odbc32.dll                             int64
#  288  apphelp.dll                            int64
#  289  dnsapi.dll                             int64
#  290  msv1_0.dll                             int64
#  291  oleaut32.dll                           int64
#  292  netapi32.dll                           int64
#  293  ntdll.dll                              int64
#  294  xpshims.dll                            int64
#  295  shdocvw.dll                            int64
#  296  mfc42.dll                              int64
#  297  ntlanman.dll                           int64
#  298  hnetcfg.dll                            int64
#  299  acroiehelper.dll                       int64
#  300  comdlg32.dll                           int64
#  301  rtutils.dll                            int64
#  302  usp10.dll                              int64
#  303  uxtheme.dll                            int64
#  304  winspool.drv                           int64
#  305  rasman.dll                             int64
#  306  mfc42u.dll                             int64
#  307  comctl32.dll                           int64
#  308  winrnr.dll                             int64
#  309  msctfime.ime                           int64
#  310  samlib.dll                             int64
#  311  rasapi32.dll                           int64
#  312  user32.dll                             int64
#  313  gdi32.dll                              int64
#  314  ogl.dll                                int64
#  315  shlwapi.dll                            int64
#  316  msimg32.dll                            int64
#  317  ieframe.dll                            int64
#  318  mshtml.dll                             int64
#  319  mscms.dll                              int64
#  320  actxprxy.dll                           int64
#  321  msvbvm60.dll                           int64
#  322  winmm.dll                              int64
#  323  msctf.dll                              int64
#  324  dciman32.dll                           int64
#  325  wbemsvc.dll                            int64
#  326  xmllite.dll                            int64
#  327  sensapi.dll                            int64
#  328  psapi.dll                              int64
#  329  mso.dll                                int64
#  330  faultrep.dll                           int64
#  331  kernel32.dll                           int64
#  332  drprov.dll                             int64
#  333  msi.dll                                int64
#  334  shell32.dll                            int64
#  335  acgenral.dll                           int64
#  336  userenv.dll                            int64
#  337  gdiplus.dll                            int64
#  338  wintrust.dll                           int64
#  339  wshtcpip.dll                           int64
#  340  imm32.dll                              int64
#  341  ntmarta.dll                            int64
#  342  olepro32.dll                           int64
#  343  rasadhlp.dll                           int64
#  344  sqmapi.dll                             int64
#  345  scrrun.dll                             int64
#  346  winhttp.dll                            int64
#  347  fastprox.dll                           int64
#  348  version.dll                            int64
#  349  wininet.dll                            int64
#  350  shfolder.dll                           int64
#  351  cscdll.dll                             int64
#  352  sxs.dll                                int64
#  353  msvfw32.dll                            int64
#  354  secur32.dll                            int64
#  355  regkey_written                         float64
#  356  regkey_opened                          float64
#  357  regkey_read                            float64
#  358  regkey_deleted                         float64
#  359  file_opened                            float64
#  360  file_written                           float64
#  361  file_exists                            float64
#  362  file_moved                             float64
#  363  file_read                              float64
#  364  file_deleted                           float64
#  365  file_failed                            float64
#  366  file_copied                            float64
#  367  directory_enumerated                   float64
#  368  directory_created                      float64
#  369  directory_removed                      float64
#  370  mutex                                  float64
#  371  processes                              float64
#  372  processtree                            float64
#  373  recon_beacon                           int64
#  374  recon_checkip                          int64
#  375  mimics_agent                           int64
#  376  antiav_detectreg                       float64
#  377  packer_upx                             float64
#  378  packer_vmprotect                       float64
#  379  packer_armadillo_regkey                int64
#  380  removes_zoneid_ads                     int64
#  381  antiemu_wine_func                      int64
#  382  network_tor                            int64
#  383  browser_helper_object                  int64
#  384  disables_wfp                           int64
#  385  antivirus_virustotal                   int64
#  386  bootkit                                int64
#  387  disables_browser_warn                  float64
#  388  browser_addon                          int64
#  389  antiav_avast_libs                      float64
#  390  disables_system_restore                float64
#  391  41antivm_generic_disk_setupapi         int64
#  392  antivm_vmware_files                    float64
#  393  packer_entropy                         float64
#  394  browser_startpage                      float64
#  395  recon_fingerprint                      float64
#  396  banker_spyeye_mutexes                  float64
#  397  disables_uac                           int64
#  398  banker_zeus_mutex                      float64
#  399  bitcoin_opencl                         float64
#  400  modify_uac_prompt                      float64
#  401  antivm_vmware_devices                  int64
#  402  infostealer_browser                    float64
#  403  antisandbox_unhook                     float64
#  404  antiav_servicestop                     int64
#  405  spoofs_procname                        int64
#  406  infostealer_mail                       float64
#  407  persistence_ads                        float64
#  408  persistence_service                    int64
#  409  stealth_file                           int64
#  410  sniffer_winpcap                        float64
#  411  driver_load                            int64
#  412  spreading_autoruninf                   float64
#  413  recon_programs                         float64
#  414  antiav_detectfile                      float64
#  415  rat_xtreme_mutexes                     int64
#  416  packer_armadillo_mutex                 int64
#  417  deepfreeze_mutex                       int64
#  418  injection_createremotethread           int64
#  419  modifies_certs                         int64
#  420  antivm_generic_services                float64
#  421  antivm_generic_diskreg                 int64
#  422  process_interest                       float64
#  423  antivm_generic_bios                    float64
#  424  antisandbox_sleep                      float64
#  425  network_icmp                           int64
#  426  injection_explorer                     int64
#  427  darkcomet_regkeys                      int64
#  428  antisandbox_suspend                    int64
#  429  network_tor_service                    int64
#  430  copies_self                            int64
#  431  pdf_page                               int64
#  432  antianalysis_detectreg                 int64
#  433  stealth_hiddenreg                      int64
#  434  mimics_filetime                        int64
#  435  rat_pcclient                           float64
#  436  reads_self                             int64
#  437  modify_proxy                           int64
#  438  stealth_network                        int64
#  439  antisandbox_mouse_hook                 float64
#  440  antisandbox_sunbelt_libs               int64
#  441  antisandbox_productid                  int64
#  442  network_http                           int64
#  443  stealth_hide_notifications             int64
#  444  antisandbox_sboxie_libs                int64
#  445  browser_security                       float64
#  446  stealth_window                         int64
#  447  ransomware_recyclebin                  int64
#  448  deletes_self                           float64
#  449  banker_cridex                          int64
#  450  banker_zeus_p2p                        float64
#  451  stealth_webhistory                     int64
#  452  rat_plugx_mutexes                      int64
#  453  antidbg_devices                        float64
#  454  antivm_generic_scsi                    float64
#  455  exec_crash                             float64
#  456  antivm_generic_disk                    float64
#  457  encrypted_ioc                          int64
#  458  network_bind                           float64
#  459  dropper                                float64
#  460  antivm_generic_cpu                     float64
#  461  creates_nullvalue                      int64
#  462  injection_rwx                          int64
#  463  antidbg_windows                        float64
#  464  disables_windowsupdate                 float64
#  465  rat_poisonivy_mutexes                  int64
#  466  polymorphic                            int64
#  467  modify_security_center_warnings        int64
#  468  prevents_safeboot                      int64
#  469  infostealer_im                         float64
#  470  infostealer_bitcoin                    float64
#  471  injection_runpe                        float64
#  472  rat_spynet                             float64
#  473  virus                                  int64
#  474  persistence_autorun                    float64
#  475  infostealer_keylog                     int64
#  476  multiple_useragents                    int64
#  477  bypass_firewall                        float64
#  478  origin_langid                          int64
#  479  process_needed                         float64
#  480  infostealer_ftp                        float64
#  481  bot_russkill                           int64
#  482  rat_fynloski_mutexes                   int64
#  483  antiemu_wine_reg                       int64
#  484  stealth_timeout                        int64
# dtypes: float64(266), int64(218), object(1)
# memory usage: 279.9+ MB

# %%
const_cols = [train_df.columns[i] for i in range(train_df.shape[1]) if train_df.iloc[:, i].nunique() <= 1]

print(f"Total constant columns: {len(const_cols)}")
print(const_cols)
# Out:
# Total constant columns: 273
# ['NtWaitForSingleObject', 'NtDeleteValueKey', 'NtCreateEvent', 'NtMakeTemporaryObject', 'NtRenameKey', 'GetLocalTime', 'NetUserGetLocalGroups', 'CryptRetrieveObjectByUrlW', 'HttpAddRequestHeadersA', 'HttpAddRequestHeadersW', 'JsEval', 'WinHttpSetTimeouts', 'WaitForDebugEvent', 'TransmitFile', 'WinHttpOpen', 'GetDiskFreeSpaceA', 'NtCreateProcess', 'WinHttpQueryHeaders', 'CryptEncrypt', 'GetSystemTime', 'FindFirstChangeNotificationW', 'HttpEndRequestW', 'HttpEndRequestA', 'ExitWindowsEx', 'WinHttpGetProxyForUrl', 'WinHttpSendRequest', 'SetupDiGetClassDevsA', 'NtQuerySystemTime', 'SetupDiGetClassDevsW', 'GetDiskFreeSpaceExA', 'NtOpenEvent', 'HttpSendRequestExW', 'WinHttpConnect', 'DbgUiWaitStateChange', 'COleScript_ParseScriptText', 'HttpSendRequestExA', 'WinHttpSetOption', 'DeleteFileA', 'NtLoadKey2', 'CryptImportPublicKeyInfo', 'VirtualProtectEx', 'FindNextFileW', 'NtCreateNamedPipeFile', 'NtReplaceKey', 'WinHttpGetIEProxyConfigForCurrentUser', 'NSPStartup', 'WinHttpReceiveResponse', 'RegNotifyChangeKeyValue', 'NtQueryMultipleValueKey', 'NtCreateProcessEx', 'GetLastInputInfo', 'InternetWriteFile', 'NtSaveKeyEx', 'SetWindowLongA', 'CDocument_write', 'WSAConnect', 'SetupDiGetDeviceRegistryPropertyW', 'LsaOpenPolicy', 'DecodeImage', 'WSAAccept', 'DnsQuery_UTF8', 'CoInternetSetFeatureEnabled', 'NtResumeProcess', 'WinHttpOpenRequest', 'SetupDiGetDeviceRegistryPropertyA', 'msxml3.dll', 'winsta.dll', 'icm32.dll', 'sqlite3.dll', 'msls31.dll', 'pstorec.dll', 'mpr.dll', 'iertutil.dll', 'crypt32.dll', 'clbcatq.dll', 'advapi32.dll', 'ole32.dll', 'ws2_32.dll', 'davclnt.dll', 'linkinfo.dll', 'mlang.dll', 'sqlite.dll', 'imgutil.dll', 'setupapi.dll', 'iphlpapi.dll', 'mswsock.dll', 'avicap32.dll', 'nss3.dll', 'msvcrt.dll', 'rpcrt4.dll', 'ieui.dll', 'ieproxy.dll', 'urlmon.dll', 'odbc32.dll', 'apphelp.dll', 'dnsapi.dll', 'msv1_0.dll', 'oleaut32.dll', 'netapi32.dll', 'ntdll.dll', 'xpshims.dll', 'shdocvw.dll', 'mfc42.dll', 'ntlanman.dll', 'hnetcfg.dll', 'acroiehelper.dll', 'comdlg32.dll', 'rtutils.dll', 'usp10.dll', 'uxtheme.dll', 'winspool.drv', 'rasman.dll', 'mfc42u.dll', 'comctl32.dll', 'winrnr.dll', 'msctfime.ime', 'samlib.dll', 'rasapi32.dll', 'user32.dll', 'gdi32.dll', 'ogl.dll', 'shlwapi.dll', 'msimg32.dll', 'ieframe.dll', 'mshtml.dll', 'mscms.dll', 'actxprxy.dll', 'msvbvm60.dll', 'winmm.dll', 'msctf.dll', 'dciman32.dll', 'wbemsvc.dll', 'xmllite.dll', 'sensapi.dll', 'psapi.dll', 'mso.dll', 'faultrep.dll', 'kernel32.dll', 'drprov.dll', 'msi.dll', 'shell32.dll', 'acgenral.dll', 'userenv.dll', 'gdiplus.dll', 'wintrust.dll', 'wshtcpip.dll', 'imm32.dll', 'ntmarta.dll', 'olepro32.dll', 'rasadhlp.dll', 'sqmapi.dll', 'scrrun.dll', 'winhttp.dll', 'fastprox.dll', 'version.dll', 'wininet.dll', 'shfolder.dll', 'cscdll.dll', 'sxs.dll', 'msvfw32.dll', 'secur32.dll', 'recon_beacon', 'recon_checkip', 'mimics_agent', 'antiav_detectreg', 'packer_upx', 'packer_vmprotect', 'packer_armadillo_regkey', 'removes_zoneid_ads', 'antiemu_wine_func', 'network_tor', 'browser_helper_object', 'disables_wfp', 'antivirus_virustotal', 'bootkit', 'disables_browser_warn', 'browser_addon', 'antiav_avast_libs', 'disables_system_restore', '41antivm_generic_disk_setupapi', 'antivm_vmware_files', 'packer_entropy', 'browser_startpage', 'recon_fingerprint', 'banker_spyeye_mutexes', 'disables_uac', 'banker_zeus_mutex', 'bitcoin_opencl', 'modify_uac_prompt', 'antivm_vmware_devices', 'infostealer_browser', 'antisandbox_unhook', 'antiav_servicestop', 'spoofs_procname', 'infostealer_mail', 'persistence_ads', 'persistence_service', 'stealth_file', 'sniffer_winpcap', 'driver_load', 'spreading_autoruninf', 'recon_programs', 'antiav_detectfile', 'rat_xtreme_mutexes', 'packer_armadillo_mutex', 'deepfreeze_mutex', 'injection_createremotethread', 'modifies_certs', 'antivm_generic_services', 'antivm_generic_diskreg', 'process_interest', 'antivm_generic_bios', 'antisandbox_sleep', 'network_icmp', 'injection_explorer', 'darkcomet_regkeys', 'antisandbox_suspend', 'network_tor_service', 'copies_self', ...

# %%
duplicates = train_df.duplicated().sum()
print(f"Duplicates: {duplicates}") 
duplicate_rows = train_df[train_df.duplicated(keep=False)]
print(duplicate_rows)

print(f"Total null values in Train: {train_df.isnull().sum().sum()}")
# Out:
# Duplicates: 25668
#        target_high_risk source_month  NtOpenSection  NtWaitForSingleObject  \
# 68162                 1  2013-04.txt            NaN                      0
# 90499                 1  2014-03.txt            NaN                      0
# 82434                 1  2014-01.txt            NaN                      0
# 87511                 1  2014-02.txt            NaN                      0
# 3179                  1  2010-11.txt            2.0                      0
# ...                 ...          ...            ...                    ...
# 769                   1  2010-11.txt            NaN                      0
# 87498                 1  2014-02.txt            NaN                      0
# 82386                 1  2014-01.txt            NaN                      0
# 6265                  1  2011-01.txt            NaN                      0
# 860                   1  2010-11.txt            NaN                      0
#
#        GetAsyncKeyState  NtDeleteValueKey  WSARecv  getaddrinfo  \
# 68162               NaN               NaN      NaN          NaN
# 90499               NaN               NaN      NaN          NaN
# 82434               NaN               NaN      NaN          NaN
# 87511               NaN               NaN      NaN          NaN
# 3179                NaN               NaN      NaN          NaN
# ...                 ...               ...      ...          ...
# 769                 NaN               NaN      NaN          NaN
# 87498               NaN               NaN      NaN          NaN
# 82386               NaN               NaN      NaN          NaN
# 6265                NaN               NaN      NaN          NaN
# 860                 NaN               NaN      NaN          NaN
#
#        InternetGetConnectedState  NtCreateEvent  ...  infostealer_keylog  \
# 68162                        NaN              0  ...                   0
# 90499                        NaN              0  ...                   0
# 82434                        NaN              0  ...                   0
# 87511                        NaN              0  ...                   0
# 3179                         NaN              0  ...                   0
# ...                          ...            ...  ...                 ...
# 769                          NaN              0  ...                   0
# 87498                        NaN              0  ...                   0
# 82386                        NaN              0  ...                   0
# 6265                         NaN              0  ...                   0
# 860                          NaN              0  ...                   0
#
#        multiple_useragents  bypass_firewall  origin_langid  process_needed  \
# 68162                    0              NaN              0             NaN
# 90499                    0              NaN              0             NaN
# 82434                    0              NaN              0             NaN
# 87511                    0              NaN              0             NaN
# 3179                     0              NaN              0             NaN
# ...                    ...              ...            ...             ...
# 769                      0              NaN              0             NaN
# 87498                    0              NaN              0             NaN
# 82386                    0              NaN              0             NaN
# 6265                     0              NaN              0             NaN
# 860                      0              NaN              0             NaN
#
#        infostealer_ftp  bot_russkill  rat_fynloski_mutexes  antiemu_wine_reg  \
# 68162              NaN             0                     0                 0
# 90499              NaN             0                     0                 0
# 82434              NaN             0                     0                 0
# 87511              NaN             0                     0                 0
# 3179               NaN             0                     0                 0
# ...                ...           ...                   ...               ...
# 769                NaN             0                     0                 0
# 87498              NaN             0                     0                 0
# 82386              NaN             0                     0                 0
# 6265               NaN             0                     0                 0
# 860                NaN             0                     0                 0
#
#        stealth_timeout
# 68162                0
# 90499                0
# 82434                0
# 87511                0
# 3179                 0
# ...                ...
# 769                  0
# 87498                0
# 82386                0
# 6265                 0
# 860                  0
#
# [29135 rows x 485 columns]
# Total null values in Train: 15927572

# %%
print(train_df['target_high_risk'].value_counts(normalize=True))
sns.countplot(x='target_high_risk', data=train_df)
plt.title('High Risk (1) vs Low Risk (0)')
plt.show()
# Out:
# target_high_risk
# 1    0.903985
# 0    0.096015
# Name: proportion, dtype: float64

# %%
null_count = train_df.isnull().mean().sort_values(ascending=False)
print("Sparsest Features (% Missing):")
print(null_count.head(50))
# Out:
# Sparsest Features (% Missing):
# banker_spyeye_mutexes        0.999987
# NtSaveKeyEx                  0.999987
# NtCreateProcessEx            0.999987
# NtRenameKey                  0.999987
# NtDeleteKey                  0.999934
# InternetWriteFile            0.999921
# NtLoadKey                    0.999907
# WSAAccept                    0.999854
# CryptExportKey               0.999828
# NtSaveKey                    0.999788
# CryptGenKey                  0.999762
# NetUserGetLocalGroups        0.999722
# rat_pcclient                 0.999656
# antivm_vmware_files          0.999629
# infostealer_im               0.999603
# SendNotifyMessageA           0.999589
# FindFirstFileExA             0.999576
# CreateDirectoryExW           0.999563
# NtQueryFullAttributesFile    0.999563
# banker_zeus_mutex            0.999285
# disables_system_restore      0.999258
# ExitWindowsEx                0.999258
# NtDeleteFile                 0.999192
# NtCreateThread               0.999152
# NtTerminateThread            0.999086
# rat_spynet                   0.998980
# antidbg_windows              0.998980
# spreading_autoruninf         0.998901
# CreateServiceW               0.998874
# disables_browser_warn        0.998861
# WSASendTo                    0.998808
# NtDeleteValueKey             0.998808
# WSARecvFrom                  0.998755
# antiav_detectfile            0.998728
# antivm_generic_bios          0.998715
# RtlCreateUserThread          0.998702
# browser_startpage            0.998689
# antidbg_devices              0.998570
# GetAddrInfoW                 0.998543
# recvfrom                     0.998490
# NtLoadDriver                 0.998291
# recv                         0.998225
# WSASend                      0.998212
# accept                       0.998185
# network_bind                 0.998185
# WSASocketW                   0.998119
# CryptDecrypt                 0.997947
# antisandbox_mouse_hook       0.997934
# modify_uac_prompt            0.997841
# antiav_detectreg             0.997788
# dtype: float64

# %%
duplicate_rows = duplicate_rows.loc[:, ~duplicate_rows.columns.duplicated()]
feature_cols = [c for c in train_df.columns if c not in ['target_high_risk', 'source_month']]
conflicts = duplicate_rows.groupby(feature_cols)['target_high_risk'].nunique()
print(f"Number of identical samples with conflicting targets: {(conflicts > 1).sum()}")
# Out:
# Number of identical samples with conflicting targets: 0

# %% [markdown]
# Defining a function to clean split dataframes

# %%
def data_clean(train_df, val_df, test_df, sparsity_threshold=0.99):
    # Dropping source_month
   train = train_df.loc[:, ~train_df.columns.duplicated()]
   val = val_df.loc[:, ~val_df.columns.duplicated()]
   test = test_df.loc[:, ~test_df.columns.duplicated()]

   cols_to_drop = ['source_month'] if 'source_month' in train.columns else []
    
    # Checking for constant columns
   for col in train.columns:
     if train[col].nunique() <= 1:
       cols_to_drop.append(col)
    
    # Checking for sparse columns
   null_pct = train.isnull().mean()
   sparse_cols = null_pct[null_pct > sparsity_threshold].index.tolist()
   cols_to_drop.extend(sparse_cols)
    
    # Unique list of all columns to remove
   final_drop_list = list(set(cols_to_drop))

    # Applying the SAME drops and removing duplicates from all sets
   def apply_clean(df):
        return df.drop(columns=final_drop_list, errors='ignore').drop_duplicates()

   return apply_clean(train), apply_clean(val), apply_clean(test)

train_cl, val_cl, test_cl = data_clean(train_df, val_df, test_df)

# %% [markdown]
# Reviewing clean data

# %%
remaining_constants = [col for col in train_cl.columns if train_cl[col].nunique() <= 1]
print(f"Constant columns remaining: {len(remaining_constants)}")

final_dupes = train_cl.duplicated().sum()
print(f"Duplicate rows remaining: {final_dupes}")

print(train_cl.dtypes.value_counts())
if 'source_month' in train_cl.columns:
    print("Data leaked")
    
null_check = train_cl.isnull().mean()
plt.figure(figsize=(10, 4))
sns.histplot(null_check, bins=20)
plt.title('Cleaned Sparsity - Check')
plt.xlabel('Percentage Missing')
plt.ylabel('Number of Features')
plt.show()
# Out:
# Constant columns remaining: 0
# Duplicate rows remaining: 0
# float64    163
# int64        1
# Name: count, dtype: int64

# %% [markdown]
# # 4: Feature engineering
# Engineering features using the provided mapping and features CSV

# %%
def features(df, mapping):
    ft_df = df.copy()

    # Defining categories from the CSV
    cats = mapping['feature_type'].unique()

    for cat in cats:
        categories = mapping[mapping['feature_type'] == cat]['feature_name'].tolist()
        # Identifying features that survived clean
        ex_features = [f for f in categories if f in ft_df.columns]

        if ex_features:
            ft_df[f'total_{cat.split("_")[0]}_intensity'] = ft_df[ex_features].sum(axis=1, min_count=1)

    return ft_df

# Applying function to the splits
train_f = features(train_cl, mapping)
val_f = features(val_cl, mapping)
test_f = features(test_cl, mapping)

# List your new aggregate features
intensity_cols = [c for c in train_f.columns if 'intensity' in c]
print("New Features Created:", intensity_cols)

# Check the distribution of one of them
print("\nSummary Statistics for Call Intensity:")
print(train_f['total_call_intensity'].describe())
# Out:
# New Features Created: ['total_call_intensity', 'total_registry_intensity', 'total_file_intensity', 'total_misc_intensity']
#
# Summary Statistics for Call Intensity:
# count     46362.000000
# mean       7203.210129
# std       14253.235038
# min           1.000000
# 25%         911.000000
# 50%        2156.000000
# 75%        5304.000000
# max      254545.000000
# Name: total_call_intensity, dtype: float64

# %%
new_feat = ['total_call_intensity', 'total_registry_intensity', 'total_file_intensity', 'total_misc_intensity']
print(train_f[new_feat + ['target_high_risk']].corr()['target_high_risk'])
# Out:
# total_call_intensity        0.090781
# total_registry_intensity   -0.000740
# total_file_intensity        0.036602
# total_misc_intensity        0.032676
# target_high_risk            1.000000
# Name: target_high_risk, dtype: float64

# %% [markdown]
# # Modelling
# Splitting into X and Y

# %%
# Defining 'targ' (target column)
targ = 'target_high_risk'

# Splitting
X_train = train_f.drop(columns=[targ])
y_train = train_f[targ]

X_val = val_f.drop(columns=[targ])
y_val = val_f[targ]

X_test = test_f.drop(columns=[targ])
y_test = test_f[targ]

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (46364, 167)
# (11139, 167)
# (11238, 167)

# %% [markdown]
# #### Defining XGBoost Classification Model

# %% [markdown]
# ####  Creating Random Search CV function to find Hyperparameters

# %%
neg = np.sum(y_train == 0)
pos = np.sum(y_train == 1)

scale_ratio = neg / pos

parameters = {
    'n_estimators': randint(200, 600),
    'learning_rate': uniform(0.05, 0.15),
    'max_depth': randint(3, 7),
    'reg_alpha': uniform(0, 1),
    'reg_lambda': uniform(0, 1),
    'subsample': uniform(0.7, 0.3),
    'colsample_bytree': uniform(0.7, 0.3),
    'scale_pos_weight': uniform(scale_ratio * 0.5, scale_ratio)}

xgb_param = XGBClassifier(
    random_state=42,
    eval_metric="logloss",
    tree_method="hist"
)

srch = RandomizedSearchCV(xgb_param, parameters, cv=3, 
                          n_iter=20, scoring='f1', n_jobs=-1, verbose=2, random_state=42)

srch.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='logloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_cons...
#                                         'reg_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f14b5fe6350>,
#                                         'reg_lambda': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f14b5fe65d0>,
#                                         'scale_pos_weight': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f14b656af90>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f14cdcdc9d0>},
#                    random_state=42, scoring='f1', verbose=2)

# %% [markdown]
# After fitting model - defining new model name and attaching optimal parameters.

# %%
# Defining a loop to print all necessary performance parameters
if hasattr(srch, 'best_params_'):
    print("Best Params:", srch.best_params_)
    print("Best CV Score:", srch.best_score_)
    
    xgb_model = srch.best_estimator_
    
    # Getting Validation set possibilities
    val_probs = xgb_model.predict_proba(X_val)[:, 1]
    # Threshold tuning
    best_threshold = 0.5
    best_metrics = (0, 0)

    for threshold in np.arange(0.30, 0.71, 0.01):
        preds = (val_probs >= threshold).astype(int)

        precision = precision_score(y_val, preds)
        recall = recall_score(y_val, preds)

        if precision >= 0.90 and recall >= 0.90:
            best_threshold = threshold
            best_metrics = (precision, recall)
            break
  
    # performance on validation set
    print(f"\nThreshold: {best_threshold}")
    val_preds = (val_probs >= best_threshold).astype(int)
    print("\n Validation report")
    print(classification_report(y_val, val_preds))

    # performance on test set
    test_probs = xgb_model.predict_proba(X_test)[:, 1]
    test_preds = (test_probs >= best_threshold).astype(int)
    print("\n Test report")
    print(classification_report(y_test, test_preds))

else:
    print("Failed search.") # Just in case of failure
# Out:
# Best Params: {'colsample_bytree': np.float64(0.9598528437324805), 'learning_rate': np.float64(0.14016725176148132), 'max_depth': 6, 'n_estimators': 330, 'reg_alpha': np.float64(0.020584494295802447), 'reg_lambda': np.float64(0.9699098521619943), 'scale_pos_weight': np.float64(0.1818941798410969), 'subsample': np.float64(0.7637017332034828)}
# Best CV Score: 0.9309452289945203
#
# Threshold: 0.3
#
#  Validation report
#               precision    recall  f1-score   support
#
#            0       0.59      0.66      0.62      1225
#            1       0.96      0.94      0.95     10013
#
#     accuracy                           0.91     11238
#    macro avg       0.77      0.80      0.79     11238
# weighted avg       0.92      0.91      0.92     11238
#
#
#  Test report
#               precision    recall  f1-score   support
#
#            0       0.60      0.68      0.64      1275
#            1       0.96      0.94      0.95      9864
#
#     accuracy                           0.91     11139
#    macro avg       0.78      0.81      0.79     11139
# weighted avg       0.92      0.91      0.91     11139

# %% [markdown]
# ### Model Visualisation
# Viewing XGBoost Model - Tuned Model
# Visualising feature importance

# %%
plt.figure(figsize=(12, 10))
feat_importances = pd.Series(xgb_model.feature_importances_, index=X_train.columns)

# Gathering top 20 Features | API calls
feat_importances.nlargest(20).plot(kind='barh', color='teal')

plt.title("Top 20 Features: High-Risk Applications")
plt.xlabel("Importance Score (Gini Importance)")
plt.ylabel("System Calls")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig("feature_importance.png")
plt.show()

# %% [markdown]
# Viewing Model Tree

# %%
os.environ["PATH"] += os.pathsep + r'C:\Users\nath_\anaconda3\Library\bin'

fig, ax = plt.subplots(figsize=(30, 15))
xgb.plot_tree(xgb_model, tree_idx=0, ax=ax)
plt.savefig("xgboost_tree.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Visualising the Precision-Recall Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test, test_preds)
auc_score = auc(recall, precision)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f'Precision-Recall Curve (AUC = {auc_score:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.savefig("Precision_recall_curve.png")
plt.show()

# %% [markdown]
# # 5: Packaging Model using pickle

# %%
xgb_model_pack = 'xgboost_model.pkl'

with open (xgb_model_pack, 'wb') as file:
    pickle.dump(xgb_model, file)

print(f"Model saved - {xgb_model_pack}")
# Out:
# Model saved - xgboost_model.pkl
